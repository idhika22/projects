# %% [markdown]
# <a href="https://colab.research.google.com/github/CowTheGreat/IETE/blob/main/NER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
nlp=spacy.load("en_core_web_sm")

# Getting the ner component
ner=nlp.get_pipe('ner')

# %%
LABEL = "GPE"
from spacy.training.example import Example

# Training examples in the required format
TRAIN_DATA =[
    ["There was a flood in Aminjikarai", {"entities": [(25, 36, "GPE")]}],
    ["Heavy rain caused flooding in Houston", {"entities": [(31, 38, "GPE")]}],
    ["The hurricane hit New Orleans", {"entities": [(18, 30, "GPE")]}],
    ["Floods are common in the Mississippi River region", {"entities": [(29, 48, "GPE")]}],
    ["Tsunami warnings in effect for Honolulu", {"entities": [(33, 41, "GPE")]}],
    ["The floodwaters in Jakarta are receding", {"entities": [(20, 26, "GPE")]}],
    ["Wildfires continue to devastate California", {"entities": [(32, 42, "GPE")]}],
    ["A tornado touched down in Oklahoma City", {"entities": [(27, 40, "GPE")]}],
    ["The typhoon hit Manila hard", {"entities": [(16, 22, "GPE")]}],
    ["Flooding is a major concern in Mumbai", {"entities": [(30, 36, "GPE")]}],
    ["Severe floods hit Tokyo last week", {"entities": [(22, 27, "GPE")]}],
    ["Recent flooding in Jakarta has caused extensive damage", {"entities": [(15, 22, "GPE")]}],
    ["New York City faces flooding during heavy rain", {"entities": [(0, 13, "GPE")]}],
    ["Paris experienced severe flooding this year", {"entities": [(0, 5, "GPE")]}],
    ["London is prone to flooding along the Thames", {"entities": [(0, 6, "GPE")]}],
    ["Venice is known for its occasional flooding", {"entities": [(0, 6, "GPE")]}],
    ["Flooding is a recurring issue in Bangkok", {"entities": [(30, 36, "GPE")]}],
    ["Sydney witnessed flooding in some suburbs", {"entities": [(0, 6, "GPE")]}],
    ["Miami faces flooding due to rising sea levels", {"entities": [(0, 5, "GPE")]}],
    ["Flooding is a concern in the Mississippi River region", {"entities": [(29, 48, "GPE")]}],
    ["Tsunami warnings in effect for Honolulu", {"entities": [(33, 41, "GPE")]}],
    ["The floodwaters in Dhaka are receding", {"entities": [(20, 25, "GPE")]}],
    ["Wildfires continue to devastate California", {"entities": [(32, 42, "GPE")]}],
    ["A tornado touched down in Oklahoma City", {"entities": [(27, 40, "GPE")]}],
    ["The typhoon hit Manila hard", {"entities": [(16, 22, "GPE")]}],
    ["Flooding is a concern in Chennai", {"entities": [(30, 36, "GPE")]}],
    ["Paris is beautiful.", {"entities": [(0, 5, "GPE")]}],
    ["I love New York.", {"entities": [(7, 15, "GPE")]}],
    ["Tokyo is huge.", {"entities": [(0, 5, "GPE")]}],
    ["Rome is ancient.", {"entities": [(0, 4, "GPE")]}],
    ["Cairo is hot.", {"entities": [(0, 5, "GPE")]}],
    ["Mexico City is busy.", {"entities": [(0, 11, "GPE")]}],
    ["Mumbai is diverse.", {"entities": [(0, 6, "GPE")]}],
    ["Sydney is sunny.", {"entities": [(0, 6, "GPE")]}],
    ["London is rainy.", {"entities": [(0, 6, "GPE")]}],
    ["Istanbul is historic.", {"entities": [(0, 8, "GPE")]}],
    ["Berlin is in Europe.", {"entities": [(0, 6, "GPE"), (10, 16, "LOC")]}],
    ["Delhi is crowded.", {"entities": [(0, 5, "GPE")]}],
    ["Chennai floods.", {"entities": [(0, 7, "GPE")]}],
    ["I am living in chennai", {"entities": [(15, 22, "GPE")]}],
    ["Amsterdam is beautiful.", {"entities": [(0, 9, "GPE")]}],
    ["She recently moved to New York City.", {"entities": [(26, 40, "GPE")]}],
    ["My friend is visiting Paris this summer.", {"entities": [(21, 26, "GPE")]}],
    ["He traveled to London for a business meeting.", {"entities": [(15, 21, "GPE")]}],
    ["They are exploring Sydney's landmarks.", {"entities": [(14, 20, "GPE")]}],
    ["Tokyo is known for its sushi.", {"entities": [(0, 5, "GPE")]}],
    ["Istanbul is a beautiful city in Turkey.", {"entities": [(0, 8, "GPE"), (31, 36, "GPE")]}],
    ["Rome, Italy, is famous for its history.", {"entities": [(0, 4, "GPE"), (6, 11, "GPE")]}],
    ["She visited Cairo, Egypt, last year.", {"entities": [(12, 17, "GPE"), (19, 24, "GPE")]}],
    ["Mexico City is the capital of Mexico.", {"entities": [(0, 11, "GPE"), (27, 32, "GPE")]}],
    ["Mumbai is a bustling city in India.", {"entities": [(0, 6, "GPE"), (30, 35, "GPE")]}],
    ["Waist-Deep Water Inside Nagpur Homes As Heavy Rain Batters Cit", {"entities": [(24, 30, "GPE")]}],
    ["Houston is famous for its space center.", {"entities": [(0, 7, "GPE")]}],
    ["Aminjikarai is a neighborhood in Chennai.", {"entities": [(0, 11, "GPE"), (25, 32, "GPE")]}],
    ["Heavy Rains Cause Flooding in Mumbai", {"entities": [(25, 31, "GPE")]}],
    ["Flooding Hits New Orleans After Heavy Rainfall", {"entities": [(15, 27, "GPE")]}],
    ["Severe Weather Alert: Flash Floods in Houston", {"entities": [(31, 38, "GPE")]}],
    ["Tsunami Warning Issued for Honolulu Coastline", {"entities": [(33, 41, "GPE")]}],
    ["Jakarta Floodwaters Recede, But Risks Remain", {"entities": [(20, 26, "GPE")]}],
    ["California Wildfires Continue to Devastate", {"entities": [(32, 42, "GPE")]}],
    ["Oklahoma City Tornado Touches Down, Causing Damage", {"entities": [(27, 40, "GPE")]}],
    ["Typhoon Hits Manila, Philippines", {"entities": [(16, 22, "GPE")]}],
    ["Mumbai Faces Major Flooding Crisis", {"entities": [(0, 6, "GPE")]}],
    ["Mississippi River Region Prepares for Flooding", {"entities": [(29, 48, "GPE")]}],
    ["Cairo Experiences Severe Weather Conditions", {"entities": [(0, 5, "GPE")]}],
    ["Mexico City Declares Emergency Amid Heavy Rainfall", {"entities": [(0, 11, "GPE")]}],
    ["Paris Undergoes Severe Flooding After Rainstorms", {"entities": [(0, 5, "GPE")]}],
    ["Tokyo Braces for Heavy Rain and Flooding", {"entities": [(0, 5, "GPE")]}],
    ["London Faces Flooding Crisis Due to Heavy Rains", {"entities": [(0, 6, "GPE")]}],
    ["A beautiful park in New York City", {"entities": [(22, 36, "GPE")]}],
    ["Visiting the historic sites in Rome", {"entities": [(27, 31, "GPE")]}],
    ["Enjoying sushi in Tokyo", {"entities": [(13, 17, "GPE")]}],
    ["Exploring the streets of Paris", {"entities": [(18, 23, "GPE")]}],
    ["Cairo, Egypt, is a city of wonders", {"entities": [(0, 4, "GPE"), (6, 11, "GPE")]}],
    ["Mexico City is known for its vibrant culture", {"entities": [(0, 11, "GPE")]}],
    ["Mumbai's bustling markets", {"entities": [(0, 6, "GPE")]}],
    ["Sydney's stunning beaches", {"entities": [(0, 6, "GPE")]}],
    ["London's iconic landmarks", {"entities": [(0, 6, "GPE")]}],
    ["Istanbul, Turkey, a city where East meets West", {"entities": [(0, 8, "GPE"), (10, 15, "GPE")]}],
    ["Berlin, Germany, a hub of creativity", {"entities": [(0, 6, "GPE"), (8, 14, "GPE")]}],
    ["Exploring the beauty of Venice, Italy", {"entities": [(20, 25, "GPE"), (27, 32, "GPE")]}],
    ["Delhi, India, a city with a rich history", {"entities": [(0, 5, "GPE"), (7, 12, "GPE")]}],
    ["Chennai's cultural heritage", {"entities": [(0, 7, "GPE")]}],
    ["Amsterdam, Netherlands, a city of canals", {"entities": [(0, 8, "GPE"), (10, 20, "GPE")]}],
    ["New York's diverse neighborhoods", {"entities": [(0, 8, "GPE")]}],
    ["Tokyo's futuristic skyline", {"entities": [(0, 5, "GPE")]}],
    ["Rome's ancient ruins", {"entities": [(0, 4, "GPE")]}],
    ["Cairo's hot desert climate", {"entities": [(0, 5, "GPE")]}],
    ["Mexico City's bustling streets", {"entities": [(0, 11, "GPE")]}],
    ["Mumbai's monsoon season", {"entities": [(0, 6, "GPE")]}],
    ["Sydney's sunny beaches", {"entities": [(0, 6, "GPE")]}],
    ["London's rainy weather", {"entities": [(0, 6, "GPE")]}],
    ["Istanbul's historic architecture", {"entities": [(0, 8, "GPE")]}],
    ["Berlin's vibrant street art scene", {"entities": [(0, 6, "GPE")]}],
    ["Heavy snowfall hit Toronto yesterday.", {"entities": [(20, 27, "GPE")]}],
    ["The beautiful beaches of Bali are a tourist attraction.", {"entities": [(127, 31, "GPE")]}],
    ["Traffic jams are common in Los Angeles.", {"entities": [(22, 34, "GPE")]}],
    ["Hiking in the Swiss Alps is a breathtaking experience.", {"entities": [(18, 28, "GPE")]}],
    ["A heatwave is expected in Phoenix this week.", {"entities": [(25, 32, "GPE")]}],
    ["The Great Wall of China stretches for miles.", {"entities": [(19, 24, "GPE")]}],
    ["Rio de Janeiro is known for its vibrant Carnival.", {"entities": [(0, 13, "GPE")]}],
    ["Heavy snowfall hit Toronto yesterday.", {"entities": [(20, 27, "GPE")]}],
    ["The beautiful beaches of Bali are a tourist attraction.", {"entities": [(27, 31, "GPE")]}],
    ["Traffic jams are common in Los Angeles.", {"entities": [(22, 34, "GPE")]}],
    ["Hiking in the Swiss Alps is a breathtaking experience.", {"entities": [(18, 28, "GPE")]}],
    ["A heatwave is expected in Phoenix this week.", {"entities": [(25, 32, "GPE")]}],
    ["The Great Wall of China stretches for miles.", {"entities": [(19, 24, "GPE")]}],
    ["Rio de Janeiro is known for its vibrant Carnival.", {"entities": [(0, 13, "GPE")]}],
    ["The Sahara Desert is the largest hot desert in the world.", {"entities": [(0, 13, "GPE")]}],
    ["Amsterdam is famous for its picturesque canals.", {"entities": [(0, 9, "GPE")]}],
    ["Boston is a historic city in the United States.", {"entities": [(0, 6, "GPE"), (27, 43, "GPE")]}],
    ["The Eiffel Tower is a symbol of Paris.", {"entities": [(29, 34, "GPE")]}],
    ["Dubai is a major financial hub in the Middle East.", {"entities": [(0, 5, "GPE"), (40, 51, "GPE")]}],
    ["Venice is famous for its gondola rides.", {"entities": [(0, 6, "GPE")]}],
    ["The Grand Canyon is a natural wonder in Arizona.", {"entities": [(4, 15, "GPE"), (27, 34, "GPE")]}],
    ["Sydney Opera House is an iconic landmark in Australia.", {"entities": [(0, 24, "GPE"), (41, 50, "GPE")]}],
    ["Auckland is the largest city in New Zealand.", {"entities": [(0, 7, "GPE"), (29, 40, "GPE")]}],
    ["The Nile River flows through multiple African countries.", {"entities": [(4, 16, "GPE")]}],
    ["Miami Beach is famous for its nightlife.", {"entities": [(0, 10, "GPE")]}],
    ["The Great Barrier Reef is off the coast of Queensland.", {"entities": [(4, 21, "GPE"), (40, 49, "GPE")]}],
    ["The Vatican City is the smallest independent state in the world.", {"entities": [(4, 16, "GPE")]}],
    ["San Francisco is known for the Golden Gate Bridge.", {"entities": [(0, 12, "GPE")]}],
    ["The Amazon Rainforest covers parts of South America.", {"entities": [(4, 21, "GPE")]}],
    ["Toronto Raptors won the NBA championship.", {"entities": [(0, 7, "GPE")]}],
    ["The Sydney Harbour Bridge is an engineering marvel.", {"entities": [(4, 16, "GPE")]}],
    ["The Colosseum in Rome is an ancient amphitheater.", {"entities": [(15, 19, "GPE")]}],
    ["Venice, Italy, is renowned for its canals.", {"entities": [(0, 6, "GPE"), (8, 13, "GPE")]}],
    ["New York City, USA, is known for its skyscrapers.", {"entities": [(0, 13, "GPE"), (15, 18, "GPE")]}],
    ["Tokyo, Japan, is famous for its sushi.", {"entities": [(0, 5, "GPE"), (7, 12, "GPE")]}],
    ["Paris, France, is renowned for its art.", {"entities": [(0, 5, "GPE"), (7, 13, "GPE")]}],
    ["The Great Barrier Reef in Australia is a natural wonder.", {"entities": [(23, 31, "GPE")]}],
    ["Cape Town, South Africa, has stunning beaches.", {"entities": [(0, 8, "GPE"), (10, 21, "GPE")]}],
    ["London, England, is home to the British Museum.", {"entities": [(0, 6, "GPE"), (8, 15, "GPE")]}],
    ["The Acropolis in Athens, Greece, is a historical site.", {"entities": [(21, 27, "GPE"), (29, 34, "GPE")]}],
    ["Rome, Italy, is famous for its ancient architecture.", {"entities": [(0, 4, "GPE"), (6, 11, "GPE")]}],
    ["The Taj Mahal in India is a symbol of love.", {"entities": [(21, 26, "GPE")]}],
    ["Sydney Opera House, Australia, is an architectural marvel.", {"entities": [(0, 18, "GPE"), (20, 27, "GPE")]}],
    ["The Pyramids of Giza, Egypt, are ancient wonders.", {"entities": [(21, 26, "GPE"), (28, 33, "GPE")]}],
    ["Rio de Janeiro, Brazil, hosts the Olympics.", {"entities": [(0, 13, "GPE"), (15, 21, "GPE")]}],
    ["Dubai, UAE, is famous for its luxury shopping.", {"entities": [(0, 5, "GPE"), (7, 10, "GPE")]}],
    ["Barcelona, Spain, is known for its unique architecture.", {"entities": [(0, 9, "GPE"), (11, 16, "GPE")]}],
    ["Bangkok, Thailand, is a bustling metropolis.", {"entities": [(0, 7, "GPE"), (9, 16, "GPE")]}],
    ["Machu Picchu, Peru, is an ancient Incan citadel.", {"entities": [(0, 12, "GPE"), (14, 18, "GPE")]}],
    ["Amsterdam, Netherlands, is famous for its canals.", {"entities": [(0, 9, "GPE"), (11, 21, "GPE")]}],
    ["The Colosseum in Rome, Italy, is an ancient amphitheater.", {"entities": [(23, 27, "GPE"), (29, 34, "GPE")]}],
    ["Venice, Italy, is renowned for its canals.", {"entities": [(0, 6, "GPE"), (8, 13, "GPE")]}],
    ["The Great Wall of China, Asia, is a UNESCO World Heritage site.", {"entities": [(20, 24, "GPE"), (26, 30, "GPE")]}],
    ["I am going to Marina beach", {"entities": [(14, 20, "GPE"),]}],
    ["She visited the Eiffel Tower", {"entities": [(20, 31, "GPE"),]}],
    ["They flew to Tokyo yesterday", {"entities": [(11, 16, "GPE"),]}],
    ["The Amazon River is in South America", {"entities": [(4, 16, "GPE"), (28, 40, "GPE"),]}],
    ["I bought a book in New York City", {"entities": [(18, 30, "GPE"),]}],
    ["He lives in London", {"entities": [(12, 18, "GPE"),]}],
    ["The Great Wall of China is famous", {"entities": [(4, 23, "GPE"),]}],
    ["They went hiking in the Alps", {"entities": [(23, 27, "GPE"),]}],
    ["I saw a movie in Hollywood", {"entities": [(17, 25, "GPE"),]}],
    ["She traveled to Paris last week", {"entities": [(17, 22, "GPE"),]}],
    ["They visited the Vatican City", {"entities": [(16, 29, "GPE"),]}],
    ["I ordered pizza in Chicago", {"entities": [(15, 22, "GPE"),]}],
    ["The Nile River flows through Africa", {"entities": [(4, 15, "GPE"), (28, 34, "GPE"),]}],
    ["He's from Sydney, Australia", {"entities": [(9, 15, "GPE"), (17, 26, "GPE"),]}],
    ["I attended a conference in Las Vegas", {"entities": [(24, 33, "GPE"),]}],
    ["She's studying in Boston", {"entities": [(17, 23, "GPE"),]}],
    ["They explored the Grand Canyon", {"entities": [(15, 27, "GPE"),]}],
    ["I visited the Colosseum in Rome", {"entities": [(22, 26, "GPE"), (8, 18, "GPE"),]}],
    ["The Sydney Opera House is iconic", {"entities": [(4, 20, "GPE"),]}],
    ["She traveled to Tokyo and Kyoto", {"entities": [(17, 22, "GPE"), (27, 32, "GPE"),]}],
    ["Paris is the capital of France", {"entities": [(0, 5, "GPE"), (21, 27, "GPE"),]}],
    ["New York City is known as the Big Apple", {"entities": [(0, 12, "GPE"), (33, 41, "GPE"),]}],
    ["The Great Wall of China is a UNESCO World Heritage Site", {"entities": [(4, 20, "GPE"),]}],
    ["Tokyo is the most populous city in Japan", {"entities": [(0, 5, "GPE"), (29, 34, "GPE"),]}],
    ["The Amazon Rainforest spans multiple South American countries", {"entities": [(4, 20, "GPE"),]}],
    ["Sydney Opera House is an iconic landmark in Australia", {"entities": [(0, 16, "GPE"), (35, 44, "GPE"),]}],
    ["London Bridge is located in London, England", {"entities": [(0, 12, "GPE"), (31, 39, "GPE"),]}],
    ["The Pyramids of Giza are ancient structures in Egypt", {"entities": [(4, 19, "GPE"), (32, 37, "GPE"),]}],
    ["Venice is famous for its canals and gondola rides", {"entities": [(0, 6, "GPE"), (29, 35, "GPE"),]}],
    ["Mount Everest is the highest peak in the Himalayas", {"entities": [(0, 13, "GPE"), (33, 42, "GPE"),]}],
    ["The Eiffel Tower is a symbol of Paris, France", {"entities": [(4, 14, "GPE"), (28, 34, "GPE"),]}],
    ["Niagara Falls is a natural wonder on the border of Canada and the United States", {"entities": [(0, 14, "GPE"), (47, 62, "GPE"),]}],
    ["Machu Picchu is an Inca citadel in Peru", {"entities": [(0, 11, "GPE"), (33, 37, "GPE"),]}],
    ["The Statue of Liberty stands in New York Harbor", {"entities": [(4, 19, "GPE"), (36, 46, "GPE"),]}],
    ["The Sahara Desert is the largest hot desert in the world", {"entities": [(4, 16, "GPE"), (42, 54, "GPE"),]}],
    ["Rio de Janeiro is known for its vibrant Carnival celebrations", {"entities": [(0, 13, "GPE"), (32, 40, "GPE"),]}],
    ["The Grand Canyon is a majestic gorge in Arizona, USA", {"entities": [(4, 16, "GPE"), (33, 43, "GPE"),]}],
    ["The Vatican City is the smallest independent state in the world", {"entities": [(4, 18, "GPE"), (52, 58, "GPE"),]}],
    ["The Sydney Harbour Bridge connects Sydney's central business district to the North Shore", {"entities": [(4, 25, "GPE"), (47, 58, "GPE"),]}],
    ["Dubai is a bustling city in the United Arab Emirates known for its luxury and modern architecture", {"entities": [(0, 5, "GPE"), (32, 54, "GPE"),]}],
    ["There was a flood in Aminjikarai", {"entities": [(25, 36, "GPE"),]}],
    ["Heavy rain caused flooding in Houston", {"entities": [(31, 38, "GPE"),]}],
    ["The hurricane hit New Orleans", {"entities": [(18, 30, "GPE"),]}],
    ["Floods are common in the Mississippi River region", {"entities": [(29, 48, "GPE"),]}],
    ["Tsunami warnings in effect for Honolulu", {"entities": [(33, 41, "GPE"),]}],
    ["The floodwaters in Jakarta are receding", {"entities": [(20, 26, "GPE"),]}],
    ["Wildfires continue to devastate California", {"entities": [(32, 42, "GPE"),]}],
    ["A tornado touched down in Oklahoma City", {"entities": [(27, 40, "GPE"),]}],
    ["The typhoon hit Manila hard", {"entities": [(16, 22, "GPE"),]}],
    ["Flooding is a major concern in Mumbai", {"entities": [(30, 36, "GPE"),]}],
    ["Severe floods hit Tokyo last week", {"entities": [(22, 27, "GPE"),]}],
    ["Recent flooding in Jakarta has caused extensive damage", {"entities": [(15, 22, "GPE"),]}],
    ["New York City faces flooding during heavy rain", {"entities": [(0, 13, "GPE"),]}],
    ["Paris experienced severe flooding this year", {"entities": [(0, 5, "GPE"),]}],
    ["London is prone to flooding along the Thames", {"entities": [(0, 6, "GPE"),]}],
    ["Venice is known for its occasional flooding", {"entities": [(0, 6, "GPE"),]}],
    ["Flooding is a recurring issue in Bangkok", {"entities": [(30, 36, "GPE"),]}],
    ["Sydney witnessed flooding in some suburbs", {"entities": [(0, 6, "GPE"),]}],
    ["Miami faces flooding due to rising sea levels", {"entities": [(0, 5, "GPE"),]}],
    ["Flooding is a concern in the Mississippi River region", {"entities": [(29, 48, "GPE"),]}],
    ["Tsunami warnings in effect for Honolulu", {"entities": [(33, 41, "GPE"),]}],
    ["The floodwaters in Dhaka are receding", {"entities": [(20, 25, "GPE"),]}],
    ["Wildfires continue to devastate California", {"entities": [(32, 42, "GPE"),]}],
    ["A tornado touched down in Oklahoma City", {"entities": [(27, 40, "GPE"),]}],
    ["The typhoon hit Manila hard", {"entities": [(16, 22, "GPE"),]}],
    ["Flooding is a concern in Chennai", {"entities": [(30, 36, "GPE"),]}],
    ["Rain flood in Houston", {"entities": [(13, 19, "GPE")]}],
    ["Heavy rain make flood in Tokyo", {"entities": [(22, 27, "GPE")]}],
    ["Big storm cause flooding in New York City", {"entities": [(31, 45, "GPE")]}],
    ["Flood happen in Mumbai last night", {"entities": [(15, 21, "GPE")]}],
    ["Tsunami warning for Honolulu beach", {"entities": [(19, 26, "GPE")]}],
    ["Wildfire destroy California forest", {"entities": [(0, 10, "GPE")]}],
    ["Strong tornado touch down Oklahoma City", {"entities": [(20, 31, "GPE")]}],
    ["Typhoon Manila hard hit", {"entities": [(8, 13, "GPE")]}],
    ["Flooding problem in Chennai", {"entities": [(16, 22, "GPE")]}],
    ["Heavy rain result in Bangkok flooding", {"entities": [(22, 28, "GPE")]}],
    ["Mississippi River flood again", {"entities": [(19, 36, "GPE")]}],
    ["Big tsunami warning for Maui", {"entities": [(19, 24, "GPE")]}],
    ["Wildfire burn Los Angeles", {"entities": [(9, 20, "GPE")]}],
    ["Flood happen London", {"entities": [(11, 17, "GPE")]}],
    ["Flooding in Paris city", {"entities": [(11, 16, "GPE")]}],
    ["Tokyo flood warning", {"entities": [(0, 5, "GPE")]}],
    ["Flooding cause chaos Jakarta", {"entities": [(17, 23, "GPE")]}],
    ["Flood crisis Mumbai", {"entities": [(12, 18, "GPE")]}],
    ["Severe flood warning in Sydney", {"entities": [(22, 28, "GPE")]}],
    ["Flood disaster New Orleans", {"entities": [(13, 24, "GPE")]}],
    ["Flooding issue in Miami", {"entities": [(16, 21, "GPE")]}],
    ["Tsunami alert Honolulu coast", {"entities": [(12, 20, "GPE")]}],
    ["Jakarta floodwater recede", {"entities": [(0, 7, "GPE")]}],
    ["California wildfire continue", {"entities": [(0, 10, "GPE")]}],
    ["Oklahoma City tornado touch down", {"entities": [(0, 14, "GPE")]}],
    ["Typhoon hit hard Manila", {"entities": [(16, 21, "GPE")]}],
    ["Chennai flooding problem", {"entities": [(8, 14, "GPE")]}],
    ["Paris beautiful city", {"entities": [(0, 5, "GPE")]}],
    ["New York love", {"entities": [(0, 8, "GPE")]}],
    ["Tokyo huge", {"entities": [(0, 5, "GPE")]}],
    ["Rome ancient", {"entities": [(0, 4, "GPE")]}],
    ["Cairo hot", {"entities": [(0, 5, "GPE")]}],
    ["Mexico City busy", {"entities": [(0, 11, "GPE")]}],
    ["Mumbai diverse", {"entities": [(0, 6, "GPE")]}],
    ["Sydney sunny", {"entities": [(0, 6, "GPE")]}],
    ["London rainy", {"entities": [(0, 6, "GPE")]}],
    ["Istanbul historic", {"entities": [(0, 8, "GPE")]}],
    ["Berlin Europe", {"entities": [(0, 6, "GPE"), (7, 13, "LOC")]}],
    ["Delhi crowded", {"entities": [(0, 5, "GPE")]}],
    ["Chennai flood", {"entities": [(0, 7, "GPE")]}],
    ["I live Chennai", {"entities": [(7, 14, "GPE")]}],
    ["Amsterdam beautiful", {"entities": [(0, 9, "GPE")]}],
    ["Recently move New York City", {"entities": [(17, 31, "GPE")]}],
    ["My friend visit Paris summer", {"entities": [(15, 20, "GPE")]}],
    ["Travel London business meeting", {"entities": [(7, 13, "GPE")]}],
    ["Explore Sydney landmarks", {"entities": [(8, 14, "GPE")]}],
    ["Tokyo sushi", {"entities": [(0, 5, "GPE")]}],
    ["Istanbul beautiful city Turkey", {"entities": [(0, 8, "GPE"), (15, 20, "GPE")]}],
    ["Rome Italy famous history", {"entities": [(0, 4, "GPE"), (5, 10, "GPE")]}],
    ["Visit Cairo Egypt year", {"entities": [(6, 11, "GPE"), (12, 17, "GPE")]}],
    ["Mexico City capital Mexico", {"entities": [(0, 11, "GPE"), (18, 23, "GPE")]}],
    ["Mumbai bustling city India", {"entities": [(0, 6, "GPE"), (13, 18, "GPE")]}],
    ["Waist-Deep Water Inside Nagpur Homes As Heavy Rain Batters Cit", {"entities": [(24, 30, "GPE")]}],
    ["Houston famous space center", {"entities": [(0, 7, "GPE")]}],
    ["Aminjikarai neighborhood Chennai", {"entities": [(0, 11, "GPE"), (12, 20, "GPE")]}],
    ["Heavy Rains Cause Flooding Mumbai", {"entities": [(25, 31, "GPE")]}],
    ["Flooding Hit New Orleans After Heavy Rainfall", {"entities": [(15, 27, "GPE")]}],
    ["Severe Weather Alert: Flash Floods Houston", {"entities": [(31, 38, "GPE")]}],
    ["Tsunami Warning Issued Honolulu Coastline", {"entities": [(33, 41, "GPE")]}],
    ["Jakarta Floodwaters Recede Risks Remain", {"entities": [(20, 26, "GPE")]}],
    ["California Wildfires Continue Devastate", {"entities": [(32, 42, "GPE")]}],
    ["Oklahoma City Tornado Touches Down Causing Damage", {"entities": [(27, 40, "GPE")]}],
    ["Typhoon Hits Hard Manila Philippines", {"entities": [(16, 22, "GPE")]}],
    ["Mumbai Faces Major Flooding Crisis", {"entities": [(0, 6, "GPE")]}],
    ["Mississippi River Region Prepares Flooding", {"entities": [(29, 48, "GPE")]}],
    ["Cairo Experiences Severe Weather Conditions", {"entities": [(0, 5, "GPE")]}],
    ["Mexico City Declares Emergency Amid Heavy Rainfall", {"entities": [(0, 11, "GPE")]}],
    ["Paris Undergoes Severe Flooding After Rainstorms", {"entities": [(0, 5, "GPE")]}],
    ["Tokyo Braces Heavy Rain Flooding", {"entities": [(0, 5, "GPE")]}],
    ["London Faces Flooding Crisis Due Heavy Rains", {"entities": [(0, 6, "GPE")]}],
    ["Flooding Concern Bangkok", {"entities": [(15, 21, "GPE")]}],
    ["Sydney Witnessed Flooding Suburbs", {"entities": [(0, 6, "GPE")]}],
    ["Miami Faces Flooding Due Rising Sea Levels", {"entities": [(0, 5, "GPE")]}],
    ["Heavy rainfall caused flooding in downtown Chicago", {"entities": [(29, 35, "GPE")]}],
    ["The monsoon season often brings floods to Dhaka, Bangladesh", {"entities": [(39, 45, "GPE")]}],
    ["Flash floods are a common occurrence in Las Vegas", {"entities": [(28, 38, "GPE")]}],
    ["Residents of Cape Town are dealing with widespread flooding", {"entities": [(13, 22, "GPE")]}],
    ["The recent storm resulted in flooding in Buenos Aires", {"entities": [(33, 44, "GPE")]}],
    ["Flooding in Rome has led to traffic disruptions", {"entities": [(11, 15, "GPE")]}],
    ["The river overflowed its banks in Sydney, Australia", {"entities": [(37, 46, "GPE")]}],
    ["Houston, Texas, experienced severe flooding last month", {"entities": [(0, 17, "GPE")]}],
    ["Flash floods are a constant threat in Nairobi", {"entities": [(28, 35, "GPE")]}],
    ["Torrential rain caused flooding in the streets of Tokyo", {"entities": [(43, 48, "GPE")]}],
    ["The floodwaters in Manila are slowly receding", {"entities": [(20, 26, "GPE")]}],
    ["Flooding in Miami Beach is a common issue", {"entities": [(12, 23, "GPE")]}],
    ["The typhoon hit Hanoi hard, causing severe flooding", {"entities": [(13, 18, "GPE")]}],
    ["Severe flooding in Jakarta has displaced thousands", {"entities": [(15, 22, "GPE")]}],
    ["Flash floods swept through Berlin last night", {"entities": [(27, 32, "GPE")]}],
    ["Aminjikarai, a neighborhood in Chennai, experienced heavy rainfall", {"entities": [(0, 11, "GPE"), (33, 40, "GPE")]}],
    ["Mumbai and Pune faced severe flooding during the monsoon", {"entities": [(0, 6, "GPE"), (11, 15, "GPE")]}],
    ["The Mississippi River region and New Orleans were hit by floods", {"entities": [(4, 23, "GPE"), (28, 40, "GPE")]}],
    ["Flash floods in Houston, Texas, caused extensive damage", {"entities": [(14, 28, "GPE"), (30, 35, "GPE")]}],
    ["Flooding in Bangkok and Phuket disrupted daily life", {"entities": [(12, 18, "GPE"), (23, 29, "GPE")]}],
    ["Jakarta and Bali experienced flooding due to heavy rains", {"entities": [(0, 7, "GPE"), (12, 16, "GPE")]}],
    ["Tsunami warnings were issued for Honolulu and Maui", {"entities": [(24, 32, "GPE"), (37, 41, "GPE")]}],
    ["Wildfires continue to devastate California, including Los Angeles", {"entities": [(32, 42, "GPE"), (52, 64, "GPE")]}],
    ["A tornado touched down in Oklahoma City, Oklahoma", {"entities": [(27, 40, "GPE"), (42, 50, "GPE")]}],
    ["The typhoon hit Manila hard in the Philippines", {"entities": [(16, 22, "GPE"), (27, 38, "GPE")]}],
    ["Flooding is a concern in Chennai, India", {"entities": [(30, 36, "GPE"), (38, 43, "GPE")]}],
    ["Severe storms caused flooding in London and Paris", {"entities": [(27, 33, "GPE"), (38, 43, "GPE")]}],
    ["Miami and Key West are facing flooding due to high tides", {"entities": [(0, 5, "GPE"), (10, 18, "GPE")]}],
    ["My favourite place is chennai", {"entities": [(22, 29, "GPE")]}],
    ["I love visiting chennai", {"entities": [(16, 23, "GPE")]}],
    ["Chennai is a beautiful city", {"entities": [(0, 7, "GPE")]}],
    ["Chennai's weather is pleasant", {"entities": [(0, 7, "GPE")]}],
    ["I am planning a trip to chennai", {"entities": [(22, 29, "GPE")]}],
    ["Chennai, located in India, is known for its culture", {"entities": [(0, 7, "GPE"), (18, 23, "GPE")]}],
    ["The beaches in chennai are stunning", {"entities": [(16, 23, "GPE")]}],
    ["I visited chennai last summer", {"entities": [(9, 16, "GPE")]}],
    ["Chennai is famous for its cuisine", {"entities": [(0, 7, "GPE")]}],
    ["My friend lives in chennai", {"entities": [(16, 23, "GPE")]}],
    ["Chennai's history is rich", {"entities": [(0, 7, "GPE")]}],
    ["I want to explore chennai", {"entities": [(19, 26, "GPE")]}],
    ["Chennai is a bustling city", {"entities": [(0, 7, "GPE")]}],
    ["Chennai is a great place to live", {"entities": [(0, 7, "GPE")]}],
    ["The culture in chennai is diverse", {"entities": [(15, 22, "GPE")]}],
    ["I dream of visiting chennai", {"entities": [(16, 23, "GPE")]}],
    ["Chennai's art scene is vibrant", {"entities": [(0, 7, "GPE")]}],
    ["I've heard so much about chennai", {"entities": [(21, 28, "GPE")]}],
    ["Chennai is on my travel list", {"entities": [(0, 7, "GPE")]}],
    ["I enjoyed my trip to chennai", {"entities": [(19, 26, "GPE")]}],
    ["Chennai's architecture is impressive", {"entities": [(0, 7, "GPE")]}],
    ["I plan to visit chennai soon", {"entities": [(19, 26, "GPE")]}],
    ["Chennai is known for its traditions", {"entities": [(0, 7, "GPE")]}],
    ["I have relatives in chennai", {"entities": [(16, 23, "GPE")]}],
    ["Chennai's education system is renowned", {"entities": [(0, 7, "GPE")]}],
    ["I'm fascinated by chennai's history", {"entities": [(18, 25, "GPE")]}],
    ["Khalistan supporters hold protest in Canada", {"entities": [(31, 37, "GPE")]}],
    ["Major Earthquake Strikes California", {"entities": [(22, 32, "GPE")]}],
    ["Political Unrest in Hong Kong Escalates", {"entities": [(25, 34, "GPE")]}],
    ["Record Heatwave Sweeps Across Australia", {"entities": [(31, 39, "GPE")]}],
    ["Protests Erupt in Paris Over New Legislation", {"entities": [(17, 22, "GPE")]}],
    ["Severe Flooding Hits New York City", {"entities": [(30, 43, "GPE")]}],
    ["London Experiences Heavy Snowfall", {"entities": [(0, 6, "GPE")]}],
    ["Tokyo Olympics Postponed Due to Pandemic", {"entities": [(0, 5, "GPE")]}],
    ["Sydney Firefighters Battle Bushfires", {"entities": [(0, 6, "GPE")]}],
    ["Rome Declares State of Emergency After Storm", {"entities": [(0, 4, "GPE")]}],
    ["Chaos at Mumbai Airport Amidst Strike", {"entities": [(8, 14, "GPE")]}],
    ["Cairo Celebrates Historic Anniversary", {"entities": [(0, 5, "GPE")]}],
    ["Mexico City Marathon Attracts Thousands", {"entities": [(0, 11, "GPE")]}],
    ["Protests Erupt in Bangkok Against Government", {"entities": [(17, 24, "GPE")]}],
    ["Tensions Rise in Istanbul Following Clashes", {"entities": [(15, 23, "GPE")]}],
    ["Berlin Zoo Welcomes Newborn Panda", {"entities": [(0, 6, "GPE")]}],
    ["Delhi Pollution Reaches Alarming Levels", {"entities": [(0, 5, "GPE")]}],
    ["Flooding in Jakarta Displaces Thousands", {"entities": [(9, 15, "GPE")]}],
    ["Wildfires Threaten Homes in California", {"entities": [(28, 38, "GPE")]}],
    ["Hong Kong Protests Continue Amidst Tensions", {"entities": [(0, 9, "GPE")]}],
    ["Paris Fashion Week Showcases Latest Trends", {"entities": [(0, 5, "GPE")]}],
    ["Typhoon Warning Issued for Manila", {"entities": [(21, 27, "GPE")]}],
    ["Tornado Strikes Oklahoma City Suburbs", {"entities": [(18, 32, "GPE")]}],
    ["Heavy Rainfall Causes Floods in Houston", {"entities": [(31, 38, "GPE")]}],
    ["Amsterdam Records Record Tourism Numbers", {"entities": [(0, 9, "GPE")]}],
    ["Bengaluru IT Sector Flourishes Amidst Pandemic", {"entities": [(0, 9, "GPE")]}],

           ]

examples = []
for text, annotation in TRAIN_DATA:
    doc = nlp.make_doc(text)
    example = Example.from_dict(doc, annotation)
    examples.append(example)

# %%
ner.add_label(LABEL)

# Resume training
optimizer = nlp.resume_training()
move_names = list(ner.move_names)

# List of pipes you want to train
pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]

# List of pipes which should remain unaffected in training
other_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]

# %%
from spacy.util import minibatch, compounding
import random

# Begin training by disabling other pipeline components
with nlp.disable_pipes(*other_pipes) :

  sizes = compounding(1.0, 4.0, 1.001)         #(1.0, 4.0, 1.001)
  # Training for 30 iterations
  for itn in range(30):
    # shuffle examples before training
    random.shuffle(TRAIN_DATA)
    # batch up the examples using spaCy's minibatch
    batches = minibatch(TRAIN_DATA, size=sizes)
    # dictionary to store losses
    losses = {}
    for batch in batches:
      texts, annotations = zip(*batch)
      # Calling update() over the iteration
    nlp.update(examples,drop=0.5,losses=losses,)
    print("Losses", losses)
# Out:
# Losses {'ner': 369.19023359519633}
# Losses {'ner': 345.2966841920985}
# Losses {'ner': 312.3577222722706}
# Losses {'ner': 279.90798002689723}
# Losses {'ner': 272.2398462222966}
# Losses {'ner': 216.8887608263891}
# Losses {'ner': 186.91653467798852}
# Losses {'ner': 211.07930374377}
# Losses {'ner': 212.46674841875281}
# Losses {'ner': 178.71975888868377}
# Losses {'ner': 179.78702676221064}
# Losses {'ner': 152.5305198289172}
# Losses {'ner': 160.93583301030273}
# Losses {'ner': 153.08479038200096}
# Losses {'ner': 154.37417999948548}
# Losses {'ner': 136.7407434396143}
# Losses {'ner': 146.92455501943567}
# Losses {'ner': 128.28155285477166}
# Losses {'ner': 118.01775667348744}
# Losses {'ner': 116.6016070425869}
# Losses {'ner': 126.26729210218848}
# Losses {'ner': 115.3559756781975}
# Losses {'ner': 113.52632978952315}
# Losses {'ner': 104.47960556105068}
# Losses {'ner': 100.02120470045085}
# Losses {'ner': 98.87574274751435}
# Losses {'ner': 103.73378065059308}
# ...

# %%
test_text = "I have been to dubai many times,I have been to russia"
doc = nlp(test_text)
print("Entities in '%s'" % test_text)
for ent in doc.ents:
  print(ent)
# Out:
# Entities in 'I have been to dubai many times,I have been to russia'
# dubai
# russia

# %%
from sklearn.metrics import classification_report

true_entities = ["Apple", "Microsoft", "Google", "OpenAI", "Amazon"]

predicted_entities = ["Apple", "Microsoft", "Tesla", "OpenAI", "Facebook"]

report = classification_report(true_entities, predicted_entities, labels=true_entities)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#        Apple       1.00      1.00      1.00         1
#    Microsoft       1.00      1.00      1.00         1
#       Google       0.00      0.00      0.00         1
#       OpenAI       1.00      1.00      1.00         1
#       Amazon       0.00      0.00      0.00         1
#
#    micro avg       1.00      0.60      0.75         5
#    macro avg       0.60      0.60      0.60         5
# weighted avg       0.60      0.60      0.60         5
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
